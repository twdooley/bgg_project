# %%
import jar
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
# %matplotlib inline

# %%
with open('xv_genres.pickle','rb') as read_file:
    df = pickle.load(read_file)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1512 entries, 13 Days: The Cuban Missile Crisis to ZÈRTZ
# Data columns (total 37 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   link                 1512 non-null   object
#  1   rank                 1512 non-null   float64
#  2   desc                 1512 non-null   object
#  3   geek                 1512 non-null   float64
#  4   rating               1512 non-null   float64
#  5   num_voters           1512 non-null   int64
#  6   price                1512 non-null   object
#  7   average              1512 non-null   float64
#  8   avgweight            1512 non-null   float64
#  9   baverage             1512 non-null   float64
#  10  maxplayers           1511 non-null   float64
#  11  maxplaytime          1511 non-null   float64
#  12  minage               1511 non-null   float64
#  13  minplayers           1511 non-null   float64
#  14  minplaytime          1511 non-null   float64
#  15  numcomments          1512 non-null   float64
#  16  numfans              1512 non-null   float64
#  17  numgeeklists         1512 non-null   float64
#  18  numhasparts          1512 non-null   float64
#  19  numowned             1512 non-null   float64
#  20  numplays             1512 non-null   float64
#  21  numplays_month       1512 non-null   float64
#  22  numprevowned         1512 non-null   float64
#  23  numtrading           1512 non-null   float64
#  24  numwanting           1512 non-null   float64
#  25  numwantparts         1512 non-null   float64
#  26  numweights           1512 non-null   float64
#  27  numwish              1512 non-null   float64
#  28  numwishlistcomments  1512 non-null   float64
#  29  playmonth            1512 non-null   object
#  30  price_mkt            822 non-null    float64
#  31  stddev               1512 non-null   float64
#  32  usersrated           1512 non-null   float64
#  33  views                1512 non-null   float64
#  34  walmart_price        191 non-null    object
#  35  yearpublished        1511 non-null   object
#  36  genres               1512 non-null   object
# dtypes: float64(29), int64(1), object(7)
# memory usage: 488.9+ KB

# %%
df.genres.value_counts()
# Out:
# Strategy                  551
# Family                    230
# Thematic                  169
# Strategy , Family         104
# War                        88
# Thematic, Strategy         81
# Party                      59
# Abstract                   36
# Customizable               27
# Thematic, Family           24
# Abstract , Family          22
# Party , Family             21
# War , Thematic             18
# War , Strategy             17
# Overall                    17
# Customizable, Strategy     11
# Abstract , Strategy         8
# Children's , Family         7
# Customizable, Thematic      6
# Children's                  6
# Thematic, Party             5
# War , Customizable          4
# null, Thematic              1
# Name: genres, dtype: int64

# %%
df['genres'] = df['genres'].replace(['null, Thematic'],'Thematic')

# %%
df.genres.value_counts()
# Out:
# Strategy                  551
# Family                    230
# Thematic                  170
# Strategy , Family         104
# War                        88
# Thematic, Strategy         81
# Party                      59
# Abstract                   36
# Customizable               27
# Thematic, Family           24
# Abstract , Family          22
# Party , Family             21
# War , Thematic             18
# War , Strategy             17
# Overall                    17
# Customizable, Strategy     11
# Abstract , Strategy         8
# Children's , Family         7
# Customizable, Thematic      6
# Children's                  6
# Thematic, Party             5
# War , Customizable          4
# Name: genres, dtype: int64

# %%
df['genres'] = df['genres'].replace(['Overall'],None)

# %%
df.genres.value_counts()
# Out:
# Strategy                  553
# Family                    232
# Thematic                  174
# Strategy , Family         108
# War                        88
# Thematic, Strategy         81
# Party                      59
# Abstract                   36
# Thematic, Family           29
# Customizable               27
# Abstract , Family          22
# Party , Family             21
# War , Thematic             18
# War , Strategy             17
# Customizable, Strategy     11
# Abstract , Strategy         8
# Children's , Family         7
# Customizable, Thematic      6
# Children's                  6
# Thematic, Party             5
# War , Customizable          4
# Name: genres, dtype: int64

# %%
len(df.genres.value_counts())
# Out:
# 21

# %%
sns.distplot(df.genres.value_counts())
# Out:
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='genres', ylabel='Density'>

# %%
plt.figure(figsize = (10,10))
sns.scatterplot('rank', 'views', data = df, hue = 'genres')
# Out:
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='rank', ylabel='views'>

# %%
df.isin({'genres': ['Strategy']})
# Out:
#                                     link   rank   desc   geek  rating  \
# 13 Days: The Cuban Missile Crisis  False  False  False  False   False
# 1775: Rebellion                    False  False  False  False   False
# 1812: The Invasion of Canada       False  False  False  False   False
# 1830: Railways & Robber Barons     False  False  False  False   False
# 1846: The Race for the Midwest     False  False  False  False   False
# ...                                  ...    ...    ...    ...     ...
# Zombicide: Green Horde             False  False  False  False   False
# Zombicide: Invader                 False  False  False  False   False
# Zombie Kidz Evolution              False  False  False  False   False
# Zooloretto                         False  False  False  False   False
# ZÈRTZ                              False  False  False  False   False
#
#                                    num_voters  price  average  avgweight  \
# 13 Days: The Cuban Missile Crisis       False  False    False      False
# 1775: Rebellion                         False  False    False      False
# 1812: The Invasion of Canada            False  False    False      False
# 1830: Railways & Robber Barons          False  False    False      False
# 1846: The Race for the Midwest          False  False    False      False
# ...                                       ...    ...      ...        ...
# Zombicide: Green Horde                  False  False    False      False
# Zombicide: Invader                      False  False    False      False
# Zombie Kidz Evolution                   False  False    False      False
# Zooloretto                              False  False    False      False
# ZÈRTZ                                   False  False    False      False
#
#                                    baverage  ...  numwish  \
# 13 Days: The Cuban Missile Crisis     False  ...    False
# 1775: Rebellion                       False  ...    False
# 1812: The Invasion of Canada          False  ...    False
# 1830: Railways & Robber Barons        False  ...    False
# 1846: The Race for the Midwest        False  ...    False
# ...                                     ...  ...      ...
# Zombicide: Green Horde                False  ...    False
# Zombicide: Invader                    False  ...    False
# Zombie Kidz Evolution                 False  ...    False
# Zooloretto                            False  ...    False
# ZÈRTZ                                 False  ...    False
#
#                                    numwishlistcomments  playmonth  price_mkt  \
# 13 Days: The Cuban Missile Crisis                False      False      False
# 1775: Rebellion                                  False      False      False
# 1812: The Invasion of Canada                     False      False      False
# 1830: Railways & Robber Barons                   False      False      False
# 1846: The Race for the Midwest                   False      False      False
# ...                                                ...        ...        ...
# Zombicide: Green Horde                           False      False      False
# Zombicide: Invader                               False      False      False
# Zombie Kidz Evolution                            False      False      False
# Zooloretto                                       False      False      False
# ZÈRTZ                                            False      False      False
#
#                                    stddev  usersrated  views  walmart_price  \
# 13 Days: The Cuban Missile Crisis   False       False  False          False
# 1775: Rebellion                     False       False  False          False
# 1812: The Invasion of Canada        False       False  False          False
# 1830: Railways & Robber Barons      False       False  False          False
# 1846: The Race for the Midwest      False       False  False          False
# ...                                   ...         ...    ...            ...
# Zombicide: Green Horde              False       False  False          False
# Zombicide: Invader                  False       False  False          False
# Zombie Kidz Evolution               False       False  False          False
# Zooloretto                          False       False  False          False
# ZÈRTZ                               False       False  False          False
#
#                                    yearpublished  genres
# 13 Days: The Cuban Missile Crisis          False   False
# 1775: Rebellion                            False   False
# 1812: The Invasion of Canada               False   False
# 1830: Railways & Robber Barons             False    True
# 1846: The Race for the Midwest             False    True
# ...                                          ...     ...
# Zombicide: Green Horde                     False   False
# Zombicide: Invader                         False   False
# Zombie Kidz Evolution                      False   False
# Zooloretto                                 False   False
# ZÈRTZ                                      False   False
#
# [1512 rows x 37 columns]

# %%
df['strat'] = 0
mask = df.genres.str.contains('Strategy')

# %%
df.loc[mask]['strat'] = 1
# Out:
# <ipython-input-105-b8615124bcdd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[mask]['strat'] = 1

# %%
df.head()
# Out:
#                                                                              link  \
# 13 Days: The Cuban Missile Crisis  /boardgame/177590/13-days-cuban-missile-crisis
# 1775: Rebellion                                  /boardgame/128996/1775-rebellion
# 1812: The Invasion of Canada                /boardgame/94246/1812-invasion-canada
# 1830: Railways & Robber Barons         /boardgame/421/1830-railways-robber-barons
# 1846: The Race for the Midwest                 /boardgame/17405/1846-race-midwest
#
#                                     rank  \
# 13 Days: The Cuban Missile Crisis  590.0
# 1775: Rebellion                    352.0
# 1812: The Invasion of Canada       826.0
# 1830: Railways & Robber Barons     184.0
# 1846: The Race for the Midwest     453.0
#
#                                                                                 desc  \
# 13 Days: The Cuban Missile Crisis  13 Days: The Cuban Missile Crisis\n(2016)\n\n\...
# 1775: Rebellion                    1775: Rebellion\n(2013)\n\n\n\t\t\tFour sides ...
# 1812: The Invasion of Canada       1812: The Invasion of Canada\n(2012)\n\n\n\t\t...
# 1830: Railways & Robber Barons     1830: Railways & Robber Barons\n(1986)\n\n\n\t...
# 1846: The Race for the Midwest     1846: The Race for the Midwest\n(2005)\n\n\n\t...
#
#                                     geek  rating  num_voters  \
# 13 Days: The Cuban Missile Crisis  6.791    7.35        3570
# 1775: Rebellion                    7.032    7.69        3583
# 1812: The Invasion of Canada       6.603    7.36        2172
# 1830: Railways & Robber Barons     7.291    7.88        4563
# 1846: The Race for the Midwest     6.929    7.96        2020
#
#                                                                                price  \
# 13 Days: The Cuban Missile Crisis  /boardgame/177590/13-days-cuban-missile-crisis...
# 1775: Rebellion                    /boardgame/128996/1775-rebellion/marketplace/g...
# 1812: The Invasion of Canada       /boardgame/94246/1812-invasion-canada/marketpl...
# 1830: Railways & Robber Barons     /boardgame/421/1830-railways-robber-barons/mar...
# 1846: The Race for the Midwest     /boardgame/17405/1846-race-midwest/marketplace...
#
#                                    average  avgweight  baverage  ...  numwish  \
# 13 Days: The Cuban Missile Crisis  7.34614     2.3592   6.79124  ...   1067.0
# 1775: Rebellion                    7.68780     2.2458   7.03249  ...   1775.0
# 1812: The Invasion of Canada       7.35633     2.1765   6.60279  ...    977.0
# 1830: Railways & Robber Barons     7.88440     4.1625   7.29190  ...   1462.0
# 1846: The Race for the Midwest     7.95666     4.0085   6.92881  ...    752.0
#
#                                    numwishlistcomments  playmonth  price_mkt  \
# 13 Days: The Cuban Missile Crisis                170.0    2020-09        NaN
# 1775: Rebellion                                  248.0    2020-09        NaN
# 1812: The Invasion of Canada                     144.0    2020-09        NaN
# 1830: Railways & Robber Barons                   245.0    2020-09     249.99
# 1846: The Race for the Midwest                   131.0    2020-09      95.00
#
#                                     stddev  usersrated     views  \
# 13 Days: The Cuban Missile Crisis  1.16019      3570.0  306695.0
# 1775: Rebellion                    1.22100      3583.0  490209.0
# 1812: The Invasion of Canada       1.23143      2172.0  300547.0
# 1830: Railways & Robber Barons     1.61384      4564.0  740254.0
# 1846: The Race for the Midwest     1.37888      2020.0  343238.0
#
#                                    walmart_price  yearpublished  \
# 13 Days: The Cuban Missile Crisis            NaN           2016
# 1775: Rebellion                              NaN           2013
# 1812: The Invasion of Canada                 NaN           2012
# 1830: Railways & Robber Barons               NaN           1986
# 1846: The Race for the Midwest               NaN           2005
#
#                                            genres
# 13 Days: The Cuban Missile Crisis  War , Strategy
# 1775: Rebellion                               War
# 1812: The Invasion of Canada       War , Strategy
# 1830: Railways & Robber Barons           Strategy
# 1846: The Race for the Midwest           Strategy
#
# [5 rows x 37 columns]

# %%
df = df.drop(['strat'], axis = 1)
