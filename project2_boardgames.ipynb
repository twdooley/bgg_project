# %%
import get_bgdf
# Out:
# {'User-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2227.1 Safari/537.36'}

# %%
import pickle
import pandas as pd

# %%
df = get_bgdf.make_bgdf()

# %%
df.sample(10)
# Out:
#                                                                                        link  \
# Gloomhaven: Jaws of the Lion                         /boardgame/291457/gloomhaven-jaws-lion
# Clank! Legacy: Acquisitions Incorporated  /boardgame/266507/clank-legacy-acquisitions-in...
# Raiders of the North Sea                                /boardgame/170042/raiders-north-sea
# Grand Austria Hotel                                   /boardgame/182874/grand-austria-hotel
# Terraforming Mars                                       /boardgame/167791/terraforming-mars
# Puerto Rico                                                     /boardgame/3076/puerto-rico
# Everdell                                                         /boardgame/199792/everdell
# Mage Knight Board Game                              /boardgame/96848/mage-knight-board-game
# Anachrony                                                       /boardgame/185343/anachrony
# ...

# %%
df.iloc[:,1]=df.iloc[:,1].astype(float)
df.iloc[:,7:29] = df.iloc[:,7:29].astype(float)
df.iloc[:,30:34]=df.iloc[:,30:34].astype(float)

# %%
df.iloc[:,24] = df.iloc[:,24].astype(str)

# %%
with open('page_1v2.pickle', 'wb') as to_write:
    pickle.dump(df, to_write)

# %%
df.iloc[9].price_mkt
# Out:
# 80.0

# %%
import seaborn as sns

# %%
sns.lmplot('price_mkt', 'rating', data = df)
# Out:
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df2 = get_bgdf.make_bgdf('/page/2')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, Tainted Grail: The Fall of Avalon to Dungeon Petz
# Data columns (total 36 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   link                 100 non-null    object
#  1   rank                 100 non-null    object
#  2   desc                 100 non-null    object
#  3   geek                 100 non-null    float64
#  4   rating               100 non-null    float64
#  5   num_voters           100 non-null    int64
#  6   price                100 non-null    object
#  7   average              100 non-null    object
#  8   avgweight            100 non-null    object
#  9   baverage             100 non-null    object
#  10  maxplayers           100 non-null    object
#  11  maxplaytime          100 non-null    object
#  12  minage               100 non-null    object
#  13  minplayers           100 non-null    object
# ...

# %%
sns.lmplot('avgweight', 'rating', data = df2)
# Out:
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-18-51005110d9b3> in <module>
# ----> 1 sns.lmplot('avgweight', 'rating', data = df2)
#
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
df3 = get_bgdf.make_bgdf('/page/3')
df3.head(10)
# Out:
#                                                                                        link  \
# Seasons                                                           /boardgame/108745/seasons
# Hanamikoji                                                     /boardgame/158600/hanamikoji
# Age of Empires III: The Age of Discovery     /boardgame/22545/age-empires-iii-age-discovery
# Pax Pamir (Second Edition)                       /boardgame/256960/pax-pamir-second-edition
# Samurai                                                                /boardgame/3/samurai
# Century: Golem Edition                              /boardgame/232832/century-golem-edition
# Dixit: Odyssey                                               /boardgame/92828/dixit-odyssey
# Space Alert                                                    /boardgame/38453/space-alert
# Dead of Winter: The Long Night                     /boardgame/193037/dead-winter-long-night
# ...

# %%
with open('page_1.pickle', 'wb') as to_write:
    pickle.dump(df, to_write)

# %%
with open('page_2v2.pickle', 'wb') as to_write:
    pickle.dump(df2, to_write)

# %%
with open('page_3v2.pickle', 'wb') as to_write:
    pickle.dump(df3, to_write)

# %%
import pandas as pd

# %%
three_pages = pd.concat([df,df2,df3])

# %%
three_pages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300 entries, Gloomhaven to Ticket to Ride: Märklin
# Data columns (total 35 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   link                 300 non-null    object
#  1   rank                 300 non-null    object
#  2   desc                 300 non-null    object
#  3   geek                 300 non-null    float64
#  4   rating               300 non-null    float64
#  5   num_voters           300 non-null    int64
#  6   price                300 non-null    object
#  7   average              300 non-null    object
#  8   avgweight            300 non-null    object
#  9   baverage             300 non-null    object
#  10  maxplayers           300 non-null    object
#  11  maxplaytime          300 non-null    object
#  12  minage               300 non-null    object
#  13  minplayers           300 non-null    object
# ...

# %%
three_pages.iloc[:,1]=three_pages.iloc[:,1].astype(float)
three_pages.iloc[:,7:29] = three_pages.iloc[:,7:29].astype(float)
three_pages.iloc[:,30:33]=three_pages.iloc[:,30:33].astype(float)
three_pages.iloc[:,33] = three_pages.iloc[:,33].replace('[\$]', '')
three_pages.iloc[:,33] = three_pages.iloc[:,33].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-0ee2564a9c02> in <module>
#       3 three_pages.iloc[:,30:33]=three_pages.iloc[:,30:33].astype(float)
#       4 three_pages.iloc[:,33] = three_pages.iloc[:,33].replace('[\$]', '')
# ----> 5 three_pages.iloc[:,33] = three_pages.iloc[:,33].astype(float)
#
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5541         else:
#    5542             # else, only a single dtype is given
# -> 5543             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5544             return self._constructor(new_data).__finalize__(self, method="astype")
#    5545
#
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
# ...

# %%
three_pages.iloc[:,33] = three_pages.iloc[:,33].astype(float, errors='ignore')

# %%
three_pages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300 entries, Gloomhaven to Ticket to Ride: Märklin
# Data columns (total 35 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   link                 300 non-null    object
#  1   rank                 300 non-null    float64
#  2   desc                 300 non-null    object
#  3   geek                 300 non-null    float64
#  4   rating               300 non-null    float64
#  5   num_voters           300 non-null    int64
#  6   price                300 non-null    object
#  7   average              300 non-null    float64
#  8   avgweight            300 non-null    float64
#  9   baverage             300 non-null    float64
#  10  maxplayers           300 non-null    float64
#  11  maxplaytime          300 non-null    float64
#  12  minage               300 non-null    float64
#  13  minplayers           300 non-null    float64
# ...

# %%
sns.lmplot('rating', '')

# %%
sns.boxplot(x=three_pages['maxplayers'], y=three_pages['rating'], hue = three_pages['minplayers'])

# %%
df4 = get_bgdf.make_bgdf('/page/4')

# %%
df4.iloc[:,1]=df4.iloc[:,1].astype(float)
df4.iloc[:,7:29] = df4.iloc[:,7:29].astype(float)
df4.iloc[:,30:34]=df4.iloc[:,30:34].astype(float)
df4.iloc[:,24] = df4.iloc[:,24].astype(str)
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, Sherlock Holmes Consulting Detective: Jack the Ripper & West End Adventures to Libertalia
# Data columns (total 36 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   link                 100 non-null    object
#  1   rank                 100 non-null    float64
#  2   desc                 100 non-null    object
#  3   geek                 100 non-null    float64
#  4   rating               100 non-null    float64
#  5   num_voters           100 non-null    int64
#  6   price                100 non-null    object
#  7   average              100 non-null    float64
#  8   avgweight            100 non-null    float64
#  9   baverage             100 non-null    float64
#  10  maxplayers           100 non-null    float64
#  11  maxplaytime          100 non-null    float64
#  12  minage               100 non-null    float64
# ...

# %%
with open('page_4v2.pickle', 'wb') as to_write:
    pickle.dump(df4, to_write)

# %%
df5 = get_bgdf.make_bgdf('/page/5')

# %%
df5.iloc[:,1]=df5.iloc[:,1].astype(float)
df5.iloc[:,7:29] = df5.iloc[:,7:29].astype(float)
df5.iloc[:,30:34]=df5.iloc[:,30:34].astype(float)
df5.iloc[:,24] = df5.iloc[:,24].astype(str)
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, Junk Art to Valeria: Card Kingdoms
# Data columns (total 36 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   link                 100 non-null    object
#  1   rank                 100 non-null    float64
#  2   desc                 100 non-null    object
#  3   geek                 100 non-null    float64
#  4   rating               100 non-null    float64
#  5   num_voters           100 non-null    int64
#  6   price                100 non-null    object
#  7   average              100 non-null    float64
#  8   avgweight            100 non-null    float64
#  9   baverage             100 non-null    float64
#  10  maxplayers           100 non-null    float64
#  11  maxplaytime          100 non-null    float64
#  12  minage               100 non-null    float64
#  13  minplayers           100 non-null    float64
# ...

# %%
with open('page_5v2.pickle', 'wb') as to_write:
    pickle.dump(df5, to_write)

# %%
df6 = get_bgdf.make_bgdf('/page/6')

# %%
df6.iloc[:,1]=df6.iloc[:,1].astype(float)
df6.iloc[:,7:29] = df6.iloc[:,7:29].astype(float)
df6.iloc[:,30:34]=df6.iloc[:,30:34].astype(float)
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, Smash Up: Awesome Level 9000 to Tajemnicze Domostwo
# Data columns (total 36 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   link                 100 non-null    object
#  1   rank                 100 non-null    float64
#  2   desc                 100 non-null    object
#  3   geek                 100 non-null    float64
#  4   rating               100 non-null    float64
#  5   num_voters           100 non-null    int64
#  6   price                100 non-null    object
#  7   average              100 non-null    float64
#  8   avgweight            100 non-null    float64
#  9   baverage             100 non-null    float64
#  10  maxplayers           100 non-null    float64
#  11  maxplaytime          100 non-null    float64
#  12  minage               100 non-null    float64
#  13  minplayers           100 non-null    float64
# ...

# %%
with open('page_6v2.pickle', 'wb') as to_write:
    pickle.dump(df6, to_write)

# %%
df7_8 = pd.concat([get_bgdf.make_bgdf('/page/7'), get_bgdf.make_bgdf('/page/8')])

# %%
df7_8.iloc[:,1]=df7_8.iloc[:,1].astype(float)
df7_8.iloc[:,7:29] = df7_8.iloc[:,7:29].astype(float)
df7_8.iloc[:,30:34]=df7_8.iloc[:,30:34].astype(float)
df7_8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, Dungeons & Dragons: The Legend of Drizzt Board Game to Draftosaurus
# Data columns (total 36 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   link                 200 non-null    object
#  1   rank                 200 non-null    float64
#  2   desc                 200 non-null    object
#  3   geek                 200 non-null    float64
#  4   rating               200 non-null    float64
#  5   num_voters           200 non-null    int64
#  6   price                200 non-null    object
#  7   average              200 non-null    float64
#  8   avgweight            200 non-null    float64
#  9   baverage             200 non-null    float64
#  10  maxplayers           199 non-null    float64
#  11  maxplaytime          199 non-null    float64
#  12  minage               199 non-null    float64
#  13  minplayers           199 non-null    float64
# ...

# %%
with open('page_7_8v2.pickle', 'wb') as to_write:
    pickle.dump(df7_8, to_write)

# %%
ten_pages = pd.concat([three_pages, four_ten])

# %%
ten_pages.tail(20)
# Out:
#                                                                                   link  \
# Hostage Negotiator                                /boardgame/134253/hostage-negotiator
# Ponzi Scheme                                            /boardgame/180899/ponzi-scheme
# Evo                                                                /boardgame/1159/evo
# Carcassonne: Winter Edition               /boardgame/131014/carcassonne-winter-edition
# Forum Trajanum                                        /boardgame/244049/forum-trajanum
# Jump Drive                                                /boardgame/205597/jump-drive
# Elfenland                                                      /boardgame/10/elfenland
# Mega Civilization                                  /boardgame/184424/mega-civilization
# BattleTech                                                  /boardgame/1540/battletech
# Council of 4                                               /boardgame/173101/council-4
# ...

# %%
ten_pages.iloc[:,1]=ten_pages.iloc[:,1].astype(float)
ten_pages.iloc[:,7:29] = ten_pages.iloc[:,7:29].astype(float)
ten_pages.iloc[:,30:34]=ten_pages.iloc[:,30:34].astype(float)

# %%
ten_pages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Gloomhaven to Thunderbirds
# Data columns (total 34 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   link                 1000 non-null   object
#  1   rank                 1000 non-null   float64
#  2   desc                 1000 non-null   object
#  3   geek                 1000 non-null   float64
#  4   rating               1000 non-null   float64
#  5   num_voters           1000 non-null   int64
#  6   price                1000 non-null   object
#  7   average              1000 non-null   float64
#  8   avgweight            1000 non-null   float64
#  9   baverage             1000 non-null   float64
#  10  maxplayers           999 non-null    float64
#  11  maxplaytime          999 non-null    float64
#  12  minage               999 non-null    float64
#  13  minplayers           999 non-null    float64
#  14  minplaytime          999 non-null    float64
# ...

# %%
with open('ten_pages_no_price.pickle', 'wb') as to_write:
    pickle.dump(ten_pages, to_write)

# %%
sns.lmplot('avgweight', 'rating', data = ten_pages)
# Out:
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot('geek', 'rating', data = ten_pages)
# Out:
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot('numfans', 'rating', data = ten_pages)
# Out:
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot('minplayers', 'rating', data = ten_pages)

# %%
with open('ten_pages_no_price.pickle','rb') as read_file:
    ten_pages = pickle.load(read_file)
    
ten_pages.head(5)
# Out:
#                                                                                  link  \
# Gloomhaven                                               /boardgame/174430/gloomhaven
# Pandemic Legacy: Season 1                  /boardgame/161936/pandemic-legacy-season-1
# Brass: Birmingham                                  /boardgame/224517/brass-birmingham
# Terraforming Mars                                 /boardgame/167791/terraforming-mars
# Twilight Imperium (Fourth Edition)  /boardgame/233078/twilight-imperium-fourth-edi...
#
#                                     rank  \
# Gloomhaven                           1.0
# Pandemic Legacy: Season 1            2.0
# Brass: Birmingham                    3.0
# Terraforming Mars                    4.0
# Twilight Imperium (Fourth Edition)   5.0
#
#                                                                                  desc  \
# Gloomhaven                          Gloomhaven\n(2017)\n\n\n\t\t\tVanquish monster...
# ...

# %%
ten_pages.desc=ten_pages.desc.replace(r'\n', '')

# %%
ten_pages[ten_pages.yearpublished <= 1000].yearpublished
# Out:
# Go                 -2200.0
# Eat Poop You Cat       0.0
# Name: yearpublished, dtype: float64

# %%
ten_pages.yearpublished.replace(
    to_replace=[1600],
    value=0,
    inplace=True
)

# %%
ten_pages[ten_pages.yearpublished <= 1000]
# Out:
#                                                link   rank  \
# Go                                /boardgame/188/go  162.0
# Eat Poop You Cat  /boardgame/30618/eat-poop-you-cat  966.0
#
#                                                                desc   geek  \
# Go                Go\n(-2200)\n\n\n\t\t\tUse stones to control s...  7.331
# Eat Poop You Cat  Eat Poop You Cat\n\n\n\t\t\tPlayers doodle and...  6.520
#
#                   rating  num_voters  \
# Go                  7.64       14403
# Eat Poop You Cat    7.48        1567
#
#                                                               price  average  \
# Go                         /boardgame/188/go/marketplace/geekmarket  7.63597
# Eat Poop You Cat  /boardgame/30618/eat-poop-you-cat/marketplace/...  7.47617
#
#                   avgweight  baverage  ...  numwanting  numwantparts  \
# Go                   3.9950   7.33090  ...       144.0           9.0
# ...

# %%
pd.to_datetime(ten_pages.yearpublished, format='%Y', errors = 'coerce')
# Out:
# Gloomhaven                              2017-01-01
# Pandemic Legacy: Season 1               2015-01-01
# Brass: Birmingham                       2018-01-01
# Terraforming Mars                       2016-01-01
# Twilight Imperium (Fourth Edition)      2017-01-01
#                                            ...
# DinoGenics                              2019-01-01
# Disney Villainous: Wicked to the Core   2019-01-01
# The Game                                2015-01-01
# The Reckoners                           2018-01-01
# Thunderbirds                            2015-01-01
# Name: yearpublished, Length: 1000, dtype: datetime64[ns]

# %%
two_thousand = ten_pages[ten_pages.yearpublished >= 2000]

# %%
sns.lmplot('yearpublished', 'rating', data = two_thousand)
# Out:
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot('yearpublished', 'avgweight', data=two_thousand)
# Out:
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
